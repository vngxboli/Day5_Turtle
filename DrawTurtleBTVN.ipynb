# %%
import turtle

#Bài 2: Vẽ và tô màu cho hình đa giác đều 10 cạnh
tl = turtle.Turtle()
tl.pensize(2)
tl.pencolor("pink")
tl.fillcolor("black")
tl.begin_fill()
tl.forward(50)
tl.left(36)
tl.forward(50)
tl.left(36)
tl.forward(50)
tl.left(36)
tl.forward(50)
tl.left(36)
tl.forward(50)
tl.left(36)
tl.forward(50)
tl.left(36)
tl.forward(50)
tl.left(36)
tl.forward(50)
tl.left(36)
tl.forward(50)
tl.left(36)
tl.forward(50)
tl.left(36)
tl.end_fill()

#Bài 1: Vẽ hình và tô màu cờ Iceland
tl.penup()
tl.right(90)
tl.forward(100)
tl.right(90)
tl.forward(30)
tl.left(90)
tl.pendown()
tl.pensize(1)
tl.pencolor("black")
tl.left(90)
tl.forward(250)
tl.right(90)
tl.forward(180)
tl.right(90)
tl.forward(250)
tl.right(90)
tl.forward(180)
tl.right(90)
tl.fillcolor("blue")
tl.begin_fill()
tl.forward(70)
tl.right(90)
tl.forward(70)
tl.right(90)
tl.forward(70)
tl.right(90)
tl.forward(70)
tl.right(90)
tl.end_fill()
tl.forward(100)
tl.fillcolor("red")
tl.begin_fill()
tl.right(90)
tl.forward(80)
tl.left(90)
tl.forward(150)
tl.right(90)
tl.forward(20)
tl.right(90)
tl.forward(150)
tl.left(90)
tl.forward(80)
tl.right(90)
tl.forward(20)
tl.right(90)
tl.forward(80)
tl.left(90)
tl.forward(80)
tl.right(90)
tl.forward(20)
tl.right(90)
tl.forward(80)
tl.left(90)
tl.forward(80)
tl.right(90)
tl.forward(20)
tl.end_fill()
tl.forward(10)
tl.fillcolor("blue")
tl.begin_fill()
tl.forward(140)
tl.right(90)
tl.forward(70)
tl.right(90)
tl.forward(140)
tl.right(90)
tl.forward(70)
tl.end_fill()
tl.right(90)
tl.forward(140)
tl.right(90)
tl.forward(110)
tl.fillcolor("blue")
tl.begin_fill()
tl.right(90)
tl.forward(140)
tl.left(90)
tl.forward(70)
tl.left(90)
tl.forward(140)
tl.end_fill()
tl.backward(250)
tl.fillcolor("blue")
tl.begin_fill()
tl.forward(70)
tl.left(90)
tl.forward(70)
tl.left(90)
tl.forward(70)
tl.left(90)
tl.forward(70)
tl.left(90)
tl.end_fill()

turtle.done()
